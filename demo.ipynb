# %%
! pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
! pip install --upgrade pip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv('Stage1_Sales_AfterSales_CRM_SCEQRY_TB.csv')
# Out:
# C:\Users\15442\AppData\Local\Temp\ipykernel_3020\1646526064.py:1: DtypeWarning: Columns (25,32,33,34,35,42,43,50,58,64,65,71,72,73,75) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Stage1_Sales_AfterSales_CRM_SCEQRY_TB.csv')

# %%
df
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE  EQRY_TEST_DRVR_DATE EQRY_FNCE_YN  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3457854 entries, 0 to 3457853
# Data columns (total 76 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   EQRY_DLR_NO             object
#  1   EQRY_ENQRY_NO           object
#  2   EQRY_CORP_NO            object
#  3   EQRY_CMPN_NO            object
#  4   EQRY_DATE               object
#  5   EQRY_SRC_CODE           object
#  6   EQRY_STAT               int64
#  7   EQRY_TYPE               object
#  8   EQRY_TEST_DRVR_DATE     float64
#  9   EQRY_FNCE_YN            object
#  10  EQRY_FNCER_CODE         object
#  11  EQRY_LOAN_AMT           float64
#  12  EQRY_TENOR_MNTHS        int64
#  13  EQRY_EXCHG_YN           object
#  14  EQRY_EXCHG_MODEL_CODE   object
#  15  EQRY_EXCHG_SRC_CODE     float64
#  16  EQRY_EXPCT_PRICE        float64
#  17  EQRY_QUOTD_PRICE        float64
#  18  EQRY_CLSE_DATE          object
#  19  EQRY_CLSE_TYPE          float64
#  20  EQRY_CLSE_RMRKS         object
# ...

# %%
df[df['EQRY_DLR_NO'].str.len().lt(10)]
# Out:
#         EQRY_DLR_NO EQRY_ENQRY_NO EQRY_CORP_NO EQRY_CMPN_NO   EQRY_DATE  \
# 0           TRAP302    E201900003        A10VA            K  2019-07-15
# 1           TRUP403    E201900001        A10VA            K  2019-07-15
# 2           TRUP403    E201900003        A10VA            K  2019-07-15
# 3           TRUP403    E201900006        A10VA            K  2019-07-16
# 4           TRUP403    E201900007        A10VA            K  2019-07-16
# ...             ...           ...          ...          ...         ...
# 3457849     TRKA310    E202202843        A10VA            K  2022-08-06
# 3457850     TRKA403    E202208509        A10VA            K  2022-08-06
# 3457851     TRJH501    E202200622        A10VA            K  2022-08-06
# 3457852     TRTN403    E202206171        A10VA            K  2022-08-06
# 3457853     TRMH406    E202207137        A10VA            K  2022-08-06
#
#         EQRY_SRC_CODE  EQRY_STAT EQRY_TYPE  EQRY_TEST_DRVR_DATE EQRY_FNCE_YN  \
# ...

# %%
findStr = df['EQRY_DLR_NO'].str.contains('Personal tragedy').any()

# %%
findStr
# Out:
# False

# %%
flag2 = df['EQRY_CLSE_RMRKS'].str.contains('Personal tragedy').any()

# %%
flag2
# Out:
# True

# %%
df.drop(['EQRY_CLSE_RMRKS'], axis=1,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3457854 entries, 0 to 3457853
# Data columns (total 75 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   EQRY_DLR_NO             object
#  1   EQRY_ENQRY_NO           object
#  2   EQRY_CORP_NO            object
#  3   EQRY_CMPN_NO            object
#  4   EQRY_DATE               object
#  5   EQRY_SRC_CODE           object
#  6   EQRY_STAT               int64
#  7   EQRY_TYPE               object
#  8   EQRY_TEST_DRVR_DATE     float64
#  9   EQRY_FNCE_YN            object
#  10  EQRY_FNCER_CODE         object
#  11  EQRY_LOAN_AMT           float64
#  12  EQRY_TENOR_MNTHS        int64
#  13  EQRY_EXCHG_YN           object
#  14  EQRY_EXCHG_MODEL_CODE   object
#  15  EQRY_EXCHG_SRC_CODE     float64
#  16  EQRY_EXPCT_PRICE        float64
#  17  EQRY_QUOTD_PRICE        float64
#  18  EQRY_CLSE_DATE          object
#  19  EQRY_CLSE_TYPE          float64
#  20  EQRY_EMP_NO             object
# ...

# %%
df.to_csv("C:\\Users\\15442\\Desktop\\Stage1_Sales_AfterSales_CRM_SCEQRY_TB.csv",index=False)

# %%
import pyarrow as pa
import pyarrow.parquet as pq

# %%
df.to_parquet('C:\\Users\\15442\\Desktop\\Stage1_Sales_AfterSales_CRM_SCEQRY_TB.parquet', engine='pyarrow')
# Out:
# ---------------------------------------------------------------------------
# ArrowTypeError                            Traceback (most recent call last)
# c:\Users\15442\Desktop\Files\ETL\demo.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/15442/Desktop/Files/ETL/demo.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df.to_parquet('C:\\Users\\15442\\Desktop\\Stage1_Sales_AfterSales_CRM_SCEQRY_TB.parquet', engine='pyarrow')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:207, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     205     else:
#     206         kwargs[new_arg_name] = new_arg_value
# --> 207 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:2835, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, **kwargs)
#    2749 """
# ...
